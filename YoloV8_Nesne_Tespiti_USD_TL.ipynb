# %% [markdown]
# ---
#
# ###  Öğrenci Bilgileri
# * **Adınız:** Barış
# * **Soyadınız:** Köse
# * **Okul Numaranız:** 2212721022
# * **GitHub Repo Bağlantısı:** https://github.com/kosebaris1/YoloV8_Nesne_Tespiti
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')

# YOLOv8 kütüphanesini kurululmu
# !pip install ultralytics
# Out:
# Mounted at /content/drive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.4 MB/s eta 0:00:00
# ...

# %%
import yaml

# Sınıf belirleme
siniflar = ['USD', 'TL']

data = {
    'train': '/content/drive/MyDrive/dataset_yolo/images/train',
    'val': '/content/drive/MyDrive/dataset_yolo/images/val',
    'nc': len(siniflar),
    'names': siniflar
}

with open('data.yaml', 'w') as f:
    yaml.dump(data, f)

print("data.yaml oluşturuldu!")
# Out:
# data.yaml oluşturuldu!

# %%
from ultralytics import YOLO

# Önceden eğitilmiş bir ağırlık ile başladık (transfer learning)
model = YOLO('yolov8n.pt')  # Nano model hızlı olduğundan tercih ettik

# epochs: kaç tur döneceği (başlangıç için 50-100 iyi olduğundan 50 seçtik)
# imgsz: resim boyutu (genelde 640)
results = model.train(data='data.yaml', epochs=50, imgsz=640, project='/content/drive/MyDrive/ProjeKlasoru/EgitimSonuclari')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
